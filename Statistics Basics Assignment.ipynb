# %% [raw]
# 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.
#
# 1. Types of Data
# Qualitative Data (Categorical Data)
# Qualitative data, also known as categorical data, describes qualities or characteristics and is non-numeric. It is typically used to label or categorize elements rather than measure them. Qualitative data answers "what type?" or "which category?"
#
# Examples of Qualitative Data:
# Gender: male, female, non-binary
# Nationality: American, Canadian, Japanese
# Blood Type: A, B, AB, O
# Survey Responses: "Satisfied," "Neutral," "Dissatisfied"
# Quantitative Data (Numerical Data)
# Quantitative data is numeric and describes quantities or amounts. It is used to measure values, allowing for mathematical calculations and analysis. Quantitative data answers "how much?" or "how many?"
#
# Examples of Quantitative Data:
# Height: 170 cm, 180 cm
# Weight: 60 kg, 75 kg
# Age: 25 years, 40 years
# Test Scores: 80%, 90%
# 2. Levels of Measurement
# The levels of measurement define the properties of the data and how they can be used in calculations or comparisons. They include nominal, ordinal, interval, and ratio scales.
#
# Nominal Scale
# The nominal scale is used for labeling or categorizing data without a specific order. It is the simplest level of measurement and is typically used for qualitative data. There is no inherent order or ranking in nominal data.
#
# Examples of Nominal Data:
# Eye color: brown, blue, green
# Type of cuisine: Italian, Chinese, Mexican
# Marital status: single, married, divorced
# Ordinal Scale
# The ordinal scale represents categories with a meaningful order or ranking, but the intervals between categories are not equal or defined. This scale is commonly used for ordered data without precise differences.
#
# Examples of Ordinal Data:
# Movie ratings: "Poor," "Average," "Good," "Excellent"
# Education level: high school, undergraduate, postgraduate
# Satisfaction level: "Very Unsatisfied," "Unsatisfied," "Neutral," "Satisfied," "Very Satisfied"
# Interval Scale
# The interval scale measures ordered data with equal intervals between values but lacks a true zero point. It allows for addition and subtraction but not for true ratios. Interval data is typically quantitative.
#
# Examples of Interval Data:
# Temperature in Celsius or Fahrenheit: 20°C, 30°C
# Time on a 12-hour clock: 3 pm, 6 pm, 9 pm
# IQ scores: 100, 110, 120
# Ratio Scale
# The ratio scale is the highest level of measurement. It has all the characteristics of an interval scale, but with a true zero point, allowing for a full range of mathematical operations, including multiplication and division. Ratio data is always quantitative.
#
# Examples of Ratio Data:
# Height: 0 cm (no height), 150 cm, 180 cm
# Weight: 0 kg, 50 kg, 100 kg
# Age: 0 years, 25 years, 40 years
# Income: $0, $30,000, $60,000

# %% [raw]
# 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median, and mode with examples and situations where each is appropriate.
#
# 1. Mean (Arithmetic Average)
# The mean is the sum of all values in a dataset divided by the number of values. It provides a measure of the "average" value and is commonly used for quantitative data.
#
# Formula:
# Mean
# =
# ∑
# (all values)
# number of values
# Mean=
# number of values
# ∑(all values)
# ​
#
#
# Example:
# Suppose the exam scores of five students are: 70, 80, 85, 90, and 100.
# Mean
# =
# 70
# +
# 80
# +
# 85
# +
# 90
# +
# 100
# 5
# =
# 85
# Mean=
# 5
# 70+80+85+90+100
# ​
#  =85
#
# When to Use the Mean:
#
# When data is quantitative and symmetric (e.g., normally distributed data).
# It is sensitive to outliers (extremely high or low values), which can skew the mean and may make it less representative in highly skewed distributions.
# Example Situation:
# Use the mean to calculate the average income in a community if the income distribution is fairly uniform without extreme outliers.
#
# 2. Median (Middle Value)
# The median is the middle value of a dataset when the values are arranged in ascending or descending order. It divides the data into two equal halves, making it a useful measure for skewed or ordinal data.
#
# Example:
# For a dataset: 70, 80, 85, 90, and 100, the median is 85 (the middle value).
#
# If there is an even number of values (e.g., 70, 80, 85, 90), the median is the average of the two middle values:
# Median
# =
# 80
# +
# 85
# 2
# =
# 82.5
# Median=
# 2
# 80+85
# ​
#  =82.5
#
# When to Use the Median:
#
# When data is skewed or contains outliers (e.g., income or house prices, where extreme values are common).
# When dealing with ordinal data, where values are ranked but not equally spaced.
# Example Situation:
# Use the median to find the central tendency of house prices in a neighborhood with a few very high or very low-priced homes, as the median is less affected by outliers.
#
# 3. Mode (Most Frequent Value)
# The mode is the value that appears most frequently in a dataset. A dataset may have one mode (unimodal), more than one mode (bimodal or multimodal), or no mode if all values are unique. The mode can be used for both qualitative and quantitative data.
#
# Example:
# For a dataset of survey responses on favorite colors: red, blue, blue, green, red, blue. The mode is "blue" because it appears most frequently.
#
# When to Use the Mode:
#
# For categorical data where you need the most common category or response.
# For discrete data with repeating values, or when analyzing popularity or frequency.
# Example Situation:
# Use the mode to find the most popular size of T-shirt sold in a store (e.g., "medium" if it is the most frequently purchased size).
#
# Summary of Measures of Central Tendency
# Measure	Definition	Data Type	Sensitive to Outliers?	Best Use Cases
# Mean	Average value	Quantitative	Yes	Symmetric distributions without outliers, e.g., average test scores.
# Median	Middle value in ordered dataset	Quantitative, ordinal	No	Skewed distributions or data with outliers, e.g., median income, house prices.
# Mode	Most frequently occurring value	Qualitative, discrete	No	Categorical or nominal data, identifying most common category, e.g., most preferred product.

# %% [raw]
# 3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#
# Dispersion refers to the extent to which values in a dataset are spread out or clustered around the center. It gives insights into the variability or spread of data points and is crucial for understanding how well the mean (or another measure of central tendency) represents the dataset. A low dispersion indicates that data points are close to the mean, while high dispersion indicates a wider spread around the mean.
#
# Two common measures of dispersion are variance and standard deviation. Both quantify the spread of data around the mean but are interpreted slightly differently.
#
# 1. Variance
# Variance measures the average squared deviation of each data point from the mean. By squaring these deviations, variance ensures that both positive and negative deviations are considered, preventing them from canceling each other out. Variance gives a general sense of how far data points are from the mean but is in squared units of the original data.
#
# Formula for Variance:
#
# For a population:
# 𝜎
# 2
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝜇
# )
# 2
# 𝑁
# σ
# 2
#  =
# N
# ∑(x
# i
# ​
#  −μ)
# 2
#
# ​
#
# For a sample:
# 𝑠
# 2
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# 𝑛
# −
# 1
# s
# 2
#  =
# n−1
# ∑(x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#
# ​
#
# Where:
#
# 𝑥
# 𝑖
# x
# i
# ​
#   represents each data point,
# 𝜇
# μ is the population mean,
# 𝑥
# ˉ
# x
# ˉ
#   is the sample mean,
# 𝑁
# N is the number of observations in the population,
# 𝑛
# n is the number of observations in the sample.
# Example: For a sample dataset with values 4, 8, and 6, the mean is 6. The squared deviations from the mean are
# (
# 4
# −
# 6
# )
# 2
# =
# 4
# (4−6)
# 2
#  =4,
# (
# 8
# −
# 6
# )
# 2
# =
# 4
# (8−6)
# 2
#  =4, and
# (
# 6
# −
# 6
# )
# 2
# =
# 0
# (6−6)
# 2
#  =0.
# Variance (sample) =
# 4
# +
# 4
# +
# 0
# 3
# −
# 1
# =
# 4
# 3−1
# 4+4+0
# ​
#  =4.
#
# Interpretation: A larger variance indicates that data points are spread out farther from the mean, while a smaller variance suggests they are closer to the mean.
#
# 2. Standard Deviation
# The standard deviation is the square root of the variance, providing a measure of spread in the same units as the data. It is a widely used measure of dispersion because it is easier to interpret than variance, especially when comparing datasets or interpreting individual deviations from the mean.
#
# Formula for Standard Deviation:
#
# For a population:
# 𝜎
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝜇
# )
# 2
# 𝑁
# σ=
# N
# ∑(x
# i
# ​
#  −μ)
# 2
#
# ​
#
# ​
#
# For a sample:
# 𝑠
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# 𝑥
# ˉ
# )
# 2
# 𝑛
# −
# 1
# s=
# n−1
# ∑(x
# i
# ​
#  −
# x
# ˉ
#  )
# 2
#
# ​
#
# ​
#
# Example: Using the previous dataset with values 4, 8, and 6, we found the variance to be 4.
# The standard deviation =
# 4
# =
# 2
# 4
# ​
#  =2.
#
# Interpretation: Standard deviation tells us how much, on average, each data point deviates from the mean. A low standard deviation indicates that values are close to the mean, while a high standard deviation indicates they are spread out.
#
# Why Variance and Standard Deviation Matter
# Variance and standard deviation are essential for understanding the spread and consistency of data. They help identify datasets with similar means but different levels of variability.
# In normally distributed data, approximately 68% of values fall within one standard deviation of the mean, 95% within two, and 99.7% within three standard deviations, providing insight into data distribution.
# Summary

# %% [raw]
# 4. What is a box plot, and what can it tell you about the distribution of data?
#
# Components of a Box Plot
# A box plot consists of several key components:
#
# Box: The box represents the interquartile range (IQR), which is the range between the first quartile (Q1) and the third quartile (Q3). It contains the middle 50% of the data.
#
# Median Line: Inside the box, a line represents the median (second quartile, Q2) of the dataset, dividing the box into two parts.
#
# Whiskers: The "whiskers" extend from the box to the minimum and maximum values within a specified range, often set to 1.5 times the IQR from Q1 and Q3. Whiskers help illustrate the spread of the data outside the IQR.
#
# Outliers: Data points that fall outside the range of the whiskers are typically considered outliers and are shown as individual points beyond the whiskers. Outliers are values that are significantly different from most of the data points and can indicate variability or potential errors.
#
# What a Box Plot Tells You About the Distribution of Data
# A box plot provides the following insights:
#
# Center of the Data: The position of the median line within the box shows the central tendency of the data. If the median is closer to the bottom or top of the box, it may indicate skewness.
#
# Spread of the Data: The length of the box (IQR) and whiskers shows the spread or variability of the data. A wider box or longer whiskers indicate greater variability, while a narrower box and shorter whiskers suggest less variability.
#
# Symmetry and Skewness:
#
# Symmetric Data: If the median line is roughly in the middle of the box and the whiskers are of similar length, the data is approximately symmetric.
# Right Skewed: If the median line is closer to Q1, and the right whisker is longer, the data is positively skewed (longer tail on the right).
# Left Skewed: If the median line is closer to Q3, and the left whisker is longer, the data is negatively skewed (longer tail on the left).
# Presence of Outliers: Individual points beyond the whiskers indicate outliers. Outliers can highlight unusual observations or possible data errors.
#
# Example Interpretation of a Box Plot
# Consider a box plot showing the distribution of test scores:
#
# Median: The median line indicates the middle score, providing a reference for typical performance.
# IQR: If the IQR is narrow, most students have similar scores; if it's wide, scores vary greatly.
# Skewness: If the plot is right-skewed, more students scored lower, with fewer high scores; if left-skewed, the opposite is true.
# Outliers: Outliers may represent students who performed exceptionally well or poorly compared to the rest.
# Summary of Insights from a Box Plot
# Feature	Interpretation
# Median line	Center or typical value of the dataset
# IQR (box)	Middle 50% of data, variability
# Whiskers	Range of data within 1.5 IQR, spread
# Outliers	Points far from the bulk of data
# Skewness	Indicated by asymmetry in box and whiskers
# Box plots are valuable for quickly assessing distribution, spotting outliers, and comparing multiple datasets. They are commonly used in exploratory data analysis and statistical summaries.

# %% [raw]
# 5. Discuss the role of random sampling in making inferences about populations.
#
# Random sampling is a fundamental technique in statistics that allows researchers to make inferences about a larger population based on a smaller sample. By selecting a subset of individuals from the population through a random process, random sampling helps ensure that the sample accurately represents the broader population. This representativeness is crucial for making valid and reliable inferences.
#
# Key Reasons for Using Random Sampling in Inference
# Reduces Bias:
#
# Random sampling minimizes selection bias by giving each member of the population an equal chance of being included. This helps avoid overrepresentation of certain groups or characteristics, making the sample more balanced and representative.
# Without random sampling, the sample might be skewed, leading to inaccurate conclusions about the population.
# Allows for Generalization:
#
# A well-designed random sample enables researchers to generalize findings from the sample to the entire population. This means that conclusions drawn about the sample are likely to hold true for the population as a whole.
# For example, if a randomly selected sample of voters shows a preference for a certain candidate, we can infer that this preference might be similar in the entire voter population.
# Supports Statistical Inference:
#
# Many statistical methods, such as confidence intervals and hypothesis testing, rely on the assumption that the sample was drawn randomly. Random sampling provides the foundation for these techniques, enabling the use of probability theory to make estimates and test hypotheses about the population.
# For example, by calculating the mean of a sample, we can use confidence intervals to estimate the range within which the population mean likely falls.
# Enables Calculation of Sampling Error:
#
# Random sampling allows for the calculation of sampling error, the natural variability that arises from using a sample rather than the full population. Sampling error provides a measure of how accurately the sample reflects the population.
# Larger random samples generally result in smaller sampling error, increasing the precision of population estimates.
# Types of Random Sampling Techniques
# There are several methods for random sampling, each suited for different research needs:
#
# Simple Random Sampling: Every member of the population has an equal chance of selection. For example, selecting names from a hat.
# Stratified Sampling: The population is divided into subgroups (strata) based on a characteristic, and random samples are taken from each stratum. This method improves accuracy for populations with distinct subgroups.
# Cluster Sampling: The population is divided into clusters (e.g., geographic areas), and a random sample of clusters is chosen, followed by sampling within selected clusters. This approach is efficient when the population is widely dispersed.
# Systematic Sampling: Every
# 𝑘
# k-th member of a population is selected after a random starting point. For example, choosing every 10th person on a list. This can approximate random sampling if the population is evenly distributed.
# Example of Random Sampling in Practice
# Imagine a researcher wants to estimate the average daily time spent on social media by university students across the country. Surveying every student is impractical, so a random sample of students from different universities is selected. If the sample is random and representative, the researcher can generalize the findings (average daily time) to all university students.
#
# Importance of Random Sampling for Valid Inference
# Without random sampling, inferences may be biased and unreliable. The results could reflect characteristics specific to the sample rather than the population. Random sampling is thus essential in statistical analysis, enhancing the accuracy, reliability, and generalizability of conclusions drawn about a population based on a sample.
#
# In summary, random sampling is key for unbiased, valid, and generalizable inferences, supporting the core objectives of statistical analysis in research.

# %% [raw]
# 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data
#
# Skewness is a measure of asymmetry in a data distribution. It describes the extent and direction of the deviation of data from a perfectly symmetrical (normal) distribution. In a normal distribution, data points are symmetrically distributed around the mean, resulting in a skewness of zero. When data is not symmetrically distributed, it exhibits skewness, which can affect how we interpret central tendency and variability.
#
# Types of Skewness
# There are two primary types of skewness:
#
# Positive Skewness (Right-Skewed):
#
# In a positively skewed (or right-skewed) distribution, the tail on the right side (higher values) is longer or fatter than the left side.
# In this case, most data points are concentrated on the lower end, with a few extreme values on the higher end.
# Effect on Mean, Median, and Mode: For positively skewed distributions, the mean is usually greater than the median, and the median is greater than the mode (Mean > Median > Mode).
# Example: Income distribution often shows positive skew, with most people earning lower to moderate incomes and a few individuals earning very high incomes.
# Negative Skewness (Left-Skewed):
#
# In a negatively skewed (or left-skewed) distribution, the tail on the left side (lower values) is longer or fatter than the right side.
# Most data points are concentrated on the higher end, with a few extreme values on the lower end.
# Effect on Mean, Median, and Mode: For negatively skewed distributions, the mean is usually less than the median, and the median is less than the mode (Mean < Median < Mode).
# Example: Age at retirement can be negatively skewed if most people retire around the same age, with a few individuals retiring much earlier.
# Zero Skewness (Symmetrical Distribution):
#
# When a distribution is symmetrical, it has no skew (skewness of zero). The left and right sides of the distribution are mirror images.
# In a perfectly symmetrical distribution, the mean, median, and mode are equal (Mean = Median = Mode).
# Example: Heights of adults in a large population often approximate a symmetrical distribution.
# How Skewness Affects the Interpretation of Data
# Measures of Central Tendency:
#
# In skewed distributions, the mean is pulled in the direction of the skew due to the influence of extreme values. Therefore, the median or mode may be a better representation of central tendency for skewed data than the mean.
# For example, in a positively skewed income distribution, the mean income may appear higher than typical incomes because it is affected by high-income outliers, while the median income would better reflect the "typical" income.
# Spread and Variability:
#
# Skewness affects how we interpret measures of dispersion like the standard deviation. In skewed data, the standard deviation may be misleading, as it does not fully account for the direction and extent of the skew.
# For instance, in a negatively skewed age-at-retirement dataset, standard deviation would show dispersion around the mean but would not capture that most individuals retire around the same age.
# Inferential Statistics and Hypothesis Testing:
#
# Many statistical tests, such as t-tests and ANOVA, assume that data is normally distributed (symmetrical). Strongly skewed data may violate these assumptions, leading to inaccurate conclusions if not adjusted.
# In such cases, researchers may need to use non-parametric tests or transform the data (e.g., logarithmic transformation) to reduce skewness.
# Decision-Making and Predictions:
#
# Skewness affects interpretation in real-world applications. In business, for instance, if sales data is positively skewed, relying on the mean sales value could lead to overestimations, as it does not represent the typical sales value due to the influence of high-value outliers.
# Understanding skewness helps decision-makers choose measures that accurately represent the dataset, reducing the likelihood of biased decisions.

# %% [raw]
# 7. What is the interquartile range (IQR), and how is it used to detect outliers?
#
# The interquartile range (IQR) is a measure of statistical dispersion, representing the range within which the middle 50% of a dataset falls. The IQR is calculated as the difference between the third quartile (Q3) and the first quartile (Q1):
#
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1
# Understanding Quartiles and the IQR
# Quartiles are values that divide a dataset into four equal parts:
#
# First Quartile (Q1): The 25th percentile, or the value below which 25% of the data points lie.
# Second Quartile (Q2): The 50th percentile, or median, where 50% of data lies below and above it.
# Third Quartile (Q3): The 75th percentile, or the value below which 75% of data points lie.
# Interquartile Range (IQR) captures the spread of the middle half of the data. It is a robust measure of variability and is less affected by extreme values, making it useful in skewed datasets.
#
# Using the IQR to Detect Outliers
# Outliers are data points that fall significantly outside the typical range of values. The IQR is commonly used to identify outliers by setting bounds for what is considered a "normal" range. These bounds are often calculated as follows:
#
# Calculate the IQR:
#
# Find Q1 and Q3.
# Calculate
# IQR
# =
# 𝑄
# 3
# −
# 𝑄
# 1
# IQR=Q3−Q1.
# Determine the Lower and Upper Bounds:
#
# Lower Bound:
# 𝑄
# 1
# −
# 1.5
# ×
# IQR
# Q1−1.5×IQR
# Upper Bound:
# 𝑄
# 3
# +
# 1.5
# ×
# IQR
# Q3+1.5×IQR
# Identify Outliers:
#
# Any data points below the lower bound or above the upper bound are considered outliers.
# This method is widely used because it provides a consistent way to detect outliers regardless of data distribution.
#
# Example of Using the IQR to Detect Outliers
# Consider the following dataset representing the test scores of students:
# 55, 60, 63, 67, 70, 75, 80, 85, 88, 95, 99
#
# Identify Q1 and Q3:
#
# Q1 (25th percentile) = 63
# Q3 (75th percentile) = 88
# Calculate the IQR:
#
# IQR
# =
# 88
# −
# 63
# =
# 25
# IQR=88−63=25
# Calculate the Bounds:
#
# Lower Bound =
# 63
# −
# (
# 1.5
# ×
# 25
# )
# =
# 63
# −
# 37.5
# =
# 25.5
# 63−(1.5×25)=63−37.5=25.5
# Upper Bound =
# 88
# +
# (
# 1.5
# ×
# 25
# )
# =
# 88
# +
# 37.5
# =
# 125.5
# 88+(1.5×25)=88+37.5=125.5
# Identify Outliers:
#
# Since all scores fall within 25.5 and 125.5, there are no outliers in this dataset.
# If any score were below 25.5 or above 125.5, it would be classified as an outlier.
#
# Why the IQR Method Is Useful for Outlier Detection
# Insensitive to Skewness: The IQR method is less affected by skewed data, unlike measures like the mean and standard deviation, which can be distorted by extreme values.
# Effective for Box Plots: The IQR is used to draw box plots, where outliers are marked as points beyond the whiskers, which represent 1.5 times the IQR from Q1 and Q3.

# %% [raw]
# 8. Discuss the conditions under which the binomial distribution is used.
#
# The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials of a binary experiment. It is widely used in situations where each trial has two possible outcomes, typically referred to as success and failure.
#
# Conditions for Using the Binomial Distribution
# To accurately apply the binomial distribution, four key conditions must be met:
#
# Fixed Number of Trials:
#
# The experiment or process consists of a fixed number of trials, denoted by
# 𝑛
# n.
# For example, if you are flipping a coin 10 times, the number of trials (
# 𝑛
# n) is 10.
# Binary Outcomes (Success or Failure):
#
# Each trial has only two possible outcomes, typically labeled as "success" and "failure."
# Examples of binary outcomes include heads or tails in a coin flip, pass or fail in a test, or defective or non-defective in a product inspection.
# Constant Probability of Success:
#
# The probability of success, denoted by
# 𝑝
# p, remains the same for each trial.
# This means that the chance of success does not change between trials. For instance, in a fair coin flip, the probability of getting heads remains 0.5 on each flip.
# Independence of Trials:
#
# The outcome of each trial is independent of the others, meaning the result of one trial does not influence the result of another.
# For example, flipping a coin multiple times satisfies independence because each flip is unaffected by previous flips.
# When these conditions are met, the binomial distribution can be used to model the probability of observing a specific number of successes in
# 𝑛
# n trials.
#
# Binomial Distribution Formula
# The probability of achieving exactly
# 𝑘
# k successes in
# 𝑛
# n trials is given by the binomial probability formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# P(X=k) is the probability of having
# 𝑘
# k successes in
# 𝑛
# n trials,
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ) is the number of ways to choose
# 𝑘
# k successes from
# 𝑛
# n trials (binomial coefficient),
# 𝑝
# p is the probability of success on a single trial,
# 1
# −
# 𝑝
# 1−p is the probability of failure on a single trial.
# Examples of When to Use the Binomial Distribution
# Quality Control:
#
# A factory produces a batch of items, and each item has a probability of being defective. If you randomly inspect 20 items, you can use the binomial distribution to calculate the probability of finding a specific number of defective items in the sample.
# Medical Studies:
#
# In a clinical trial, each patient has a probability of responding positively to a new drug. If there are 100 patients, the binomial distribution can help estimate the probability that a certain number of patients will respond to the treatment.
# Survey Analysis:
#
# In a survey, each respondent has a probability of agreeing with a statement. If you survey 500 people, the binomial distribution can estimate the probability of a given number of respondents agreeing with the statement.
# Key Properties of the Binomial Distribution
# Mean: The mean (expected value) of a binomial distribution is given by
# 𝜇
# =
# 𝑛
# ×
# 𝑝
# μ=n×p.
# Variance: The variance of a binomial distribution is
# 𝜎
# 2
# =
# 𝑛
# ×
# 𝑝
# ×
# (
# 1
# −
# 𝑝
# )
# σ
# 2
#  =n×p×(1−p).
# Shape: The shape of the binomial distribution depends on the values of
# 𝑛
# n and
# 𝑝
# p. For larger
# 𝑛
# n and when
# 𝑝
# p is close to 0.5, the distribution appears more symmetric. When
# 𝑝
# p is closer to 0 or 1, the distribution becomes more skewed.
# Summary
# The binomial distribution is suitable for situations that meet the following conditions:
#
# Condition	Description
# Fixed Number of Trials	A predetermined, finite number of trials
# Binary Outcomes	Only two outcomes: success or failure
# Constant Probability of Success	Probability
# 𝑝
# p remains unchanged
# Independence of Trials	Each trial's outcome is independent
# When these criteria are satisfied, the binomial distribution is a powerful tool for modeling and analyzing the likelihood of different numbers of successes, aiding in decision-making and statistical inference across various fields.

# %% [raw]
# 9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule)
#
# The normal distribution is a continuous probability distribution that is symmetrical and bell-shaped, commonly used to model many natural and social phenomena. The shape and properties of the normal distribution make it foundational in statistics, especially when analyzing data that are assumed to be normally distributed.
#
# Properties of the Normal Distribution
# Symmetry:
#
# The normal distribution is perfectly symmetric about its mean (
# 𝜇
# μ), meaning the left and right sides of the distribution are mirror images of each other.
# Because of this symmetry, the mean, median, and mode of the distribution are all equal.
# Bell Shape:
#
# The distribution’s shape resembles a bell, with most data points concentrated around the mean, and frequencies gradually decreasing as they move away from the center.
# Asymptotic:
#
# The tails of the normal distribution approach, but never touch, the horizontal axis. This means that extreme values, while unlikely, are still possible.
# Mean and Standard Deviation:
#
# The shape and position of a normal distribution are determined by its mean (
# 𝜇
# μ) and standard deviation (
# 𝜎
# σ).
# The mean defines the center of the distribution, while the standard deviation determines the spread or width of the bell curve. A larger standard deviation results in a wider, flatter curve, while a smaller standard deviation results in a narrower, taller curve.
# Total Area Equals 1:
#
# The area under the curve of a normal distribution represents probability, with a total area equal to 1 (or 100%), covering all possible outcomes.
# The Empirical Rule (68-95-99.7 Rule)
# The Empirical Rule describes the spread of data within a normal distribution in terms of standard deviations from the mean. It states that in a normal distribution:
#
# 68% of Data within 1 Standard Deviation:
#
# Approximately 68% of the data falls within one standard deviation (
# 𝜇
# ±
# 𝜎
# μ±σ) of the mean.
# For example, if the mean score on a test is 70 with a standard deviation of 10, about 68% of scores will fall between 60 and 80.
# 95% of Data within 2 Standard Deviations:
#
# Approximately 95% of the data falls within two standard deviations (
# 𝜇
# ±
# 2
# 𝜎
# μ±2σ) of the mean.
# In the test score example, about 95% of scores will fall between 50 and 90.
# 99.7% of Data within 3 Standard Deviations:
#
# Approximately 99.7% of the data falls within three standard deviations (
# 𝜇
# ±
# 3
# 𝜎
# μ±3σ) of the mean.
# Continuing with the test score example, nearly all scores (99.7%) will be between 40 and 100.
# This rule is especially useful for quickly estimating the spread of data and identifying potential outliers in a dataset. Any data point beyond three standard deviations from the mean (on either side) is very unusual, occurring in only 0.3% of cases in a perfectly normal distribution.
#
# Applications of the Normal Distribution and Empirical Rule
# Quality Control: The Empirical Rule helps set acceptable limits for product measurements and identify outliers that could signal quality issues.
# Standardized Testing: Scores on standardized tests like the SAT often follow a normal distribution, allowing comparisons between individuals based on standard deviations from the mean.
# Risk Management: The normal distribution is used in finance to model risk, such as stock returns, where outcomes within 1 or 2 standard deviations are considered typical, while 3 standard deviations indicate a rare, significant event.

# %% [raw]
# 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
#
# A Poisson process is a statistical process that models the occurrence of events happening at a constant average rate over a fixed period of time or space, where the events are independent of each other. The Poisson distribution is used to calculate the probability of a given number of events occurring within a fixed interval.
#
# Real-Life Example of a Poisson Process
# Example: Call Center Calls
#
# Let’s consider a call center where calls are received at a constant average rate. Suppose, on average, the call center receives 6 calls per hour. We can model this scenario as a Poisson process, where the number of calls received in an hour is a Poisson random variable.
#
# The key assumptions here are:
#
# Calls arrive independently of each other.
# The average rate of calls is constant over time.
# The number of calls in one time period (e.g., an hour) is independent of the number in another time period.
# Poisson Distribution Formula
# The Poisson distribution formula is used to calculate the probability of observing exactly
# 𝑘
# k events in a fixed interval when events occur at a known average rate:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝜆
# 𝑘
# 𝑒
# −
# 𝜆
# 𝑘
# !
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#
# Where:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# P(X=k) is the probability of observing exactly
# 𝑘
# k events (e.g., calls).
# 𝜆
# λ is the average number of events in the interval (e.g., the average number of calls per hour).
# 𝑘
# k is the number of events we want to find the probability for (e.g., the number of calls).
# 𝑒
# e is Euler’s number (
# ≈
# 2.718
# ≈2.718).
# 𝑘
# !
# k! is the factorial of
# 𝑘
# k, which is the product of all positive integers up to
# 𝑘
# k.
# Example Calculation
# Problem: What is the probability that exactly 4 calls are received in a 1-hour period?
#
# We know that the average rate of calls is 6 calls per hour, so
# 𝜆
# =
# 6
# λ=6 and we want to calculate the probability of exactly 4 calls, i.e.,
# 𝑘
# =
# 4
# k=4.
#
# Using the Poisson formula:
#
# 𝑃
# (
# 𝑋
# =
# 4
# )
# =
# 6
# 4
# 𝑒
# −
# 6
# 4
# !
# P(X=4)=
# 4!
# 6
# 4
#  e
# −6
#
# ​
#
# First, calculate the components:
#
# 6
# 4
# =
# 1296
# 6
# 4
#  =1296
# 𝑒
# −
# 6
# ≈
# 0.00247875
# e
# −6
#  ≈0.00247875
# 4
# !
# =
# 4
# ×
# 3
# ×
# 2
# ×
# 1
# =
# 24
# 4!=4×3×2×1=24
# Now, substitute these into the formula:
#
# 𝑃
# (
# 𝑋
# =
# 4
# )
# =
# 1296
# ×
# 0.00247875
# 24
# P(X=4)=
# 24
# 1296×0.00247875
# ​
#
# 𝑃
# (
# 𝑋
# =
# 4
# )
# ≈
# 3.216
# 24
# =
# 0.134
# P(X=4)≈
# 24
# 3.216
# ​
#  =0.134
# Thus, the probability that exactly 4 calls are received in an hour is approximately 0.134, or 13.4%.
#
# Interpretation of the Result
# This means there is a 13.4% chance that exactly 4 calls will be received in a 1-hour period, given that the average number of calls is 6 per hour.

# %% [raw]
# 11. Explain what a random variable is and differentiate between discrete and continuous random variables.
#
# Random Variable
# A random variable is a numerical outcome of a random process or experiment. It represents a quantity whose value is determined by the outcome of a random event. The value of a random variable is uncertain and can vary, depending on the outcomes of the random experiment.
#
# There are two main types of random variables: discrete and continuous. The difference between them lies in the nature of their possible values.
#
# Discrete Random Variables
# A discrete random variable is one that can take on a countable number of distinct values. These values are often integers, but they could be any set of distinct, separate values (e.g., 1, 2, 3, etc.). Discrete random variables are often the result of counting something.
#
# Key Characteristics:
# Countable outcomes: The values can be counted, even if the number is infinite (like counting the number of heads in a series of coin flips).
# Examples: The number of cars passing a toll booth in an hour, the number of students in a class, the number of defective items in a batch, etc.
# Example:
# Let
# 𝑋
# X be the number of heads when flipping a coin 3 times.
# 𝑋
# X can take the values 0, 1, 2, or 3, because those are the possible number of heads in 3 flips.
# Continuous Random Variables
# A continuous random variable is one that can take on any value within a certain range or interval. The values are not countable but instead can take on an infinite number of possibilities, typically within a given range. Continuous random variables usually result from measurements.
#
# Key Characteristics:
# Uncountable outcomes: The possible values form a continuum (e.g., any value between 0 and 1, or any height of a person).
# Examples: Height, weight, temperature, time, distance, etc.
# These variables are typically measured and can have an infinite number of possible outcomes in any given range.
# Example:
# Let
# 𝑌
# Y be the time it takes for a person to run a 100-meter dash.
# 𝑌
# Y could take any value, like 9.52 seconds, 9.523 seconds, and so on, with an infinite number of possibilities in a range of values.

# %% [raw]
# 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
#
# Let's walk through an example where we calculate covariance and correlation for a dataset, and interpret the results.
#
# Example Dataset: Students' Study Hours and Exam Scores
# Suppose we have the following data on the number of hours studied and the exam scores of 5 students:
#
# Student	Hours Studied (X)	Exam Score (Y)
# A	3	60
# B	4	65
# C	5	70
# D	6	75
# E	7	80
# Step 1: Calculate the Mean of Each Variable
# Mean of Hours Studied (X):
#
# 𝑋
# ˉ
# =
# 3
# +
# 4
# +
# 5
# +
# 6
# +
# 7
# 5
# =
# 25
# 5
# =
# 5
# X
# ˉ
#  =
# 5
# 3+4+5+6+7
# ​
#  =
# 5
# 25
# ​
#  =5
# Mean of Exam Scores (Y):
#
# 𝑌
# ˉ
# =
# 60
# +
# 65
# +
# 70
# +
# 75
# +
# 80
# 5
# =
# 350
# 5
# =
# 70
# Y
# ˉ
#  =
# 5
# 60+65+70+75+80
# ​
#  =
# 5
# 350
# ​
#  =70
# Step 2: Calculate Covariance
# The formula for covariance between two variables
# 𝑋
# X and
# 𝑌
# Y is:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# Cov(X,Y)=
# n
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# Where:
#
# 𝑋
# 𝑖
# X
# i
# ​
#   and
# 𝑌
# 𝑖
# Y
# i
# ​
#   are individual data points,
# 𝑋
# ˉ
# X
# ˉ
#   and
# 𝑌
# ˉ
# Y
# ˉ
#   are the means of
# 𝑋
# X and
# 𝑌
# Y,
# 𝑛
# n is the number of data points (here
# 𝑛
# =
# 5
# n=5).
# Now, calculate each product of deviations from the mean for
# 𝑋
# X and
# 𝑌
# Y:
#
# Student
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# X
# i
# ​
#  −
# X
# ˉ
#
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# Y
# i
# ​
#  −
# Y
# ˉ
#
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# (
# 𝑌
# 𝑖
# −
# 𝑌
# ˉ
# )
# (X
# i
# ​
#  −
# X
# ˉ
#  )(Y
# i
# ​
#  −
# Y
# ˉ
#  )
# A	3 - 5 = -2	60 - 70 = -10	(-2) × (-10) = 20
# B	4 - 5 = -1	65 - 70 = -5	(-1) × (-5) = 5
# C	5 - 5 = 0	70 - 70 = 0	0 × 0 = 0
# D	6 - 5 = 1	75 - 70 = 5	1 × 5 = 5
# E	7 - 5 = 2	80 - 70 = 10	2 × 10 = 20
# Now, sum the products:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# =
# 1
# 5
# (
# 20
# +
# 5
# +
# 0
# +
# 5
# +
# 20
# )
# =
# 50
# 5
# =
# 10
# Cov(X,Y)=
# 5
# 1
# ​
#  (20+5+0+5+20)=
# 5
# 50
# ​
#  =10
# So, the covariance between Hours Studied and Exam Score is 10.
#
# Step 3: Calculate Correlation
# The formula for correlation
# 𝑟
# r is:
#
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#
# Where:
#
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# Cov(X,Y) is the covariance we just calculated,
# 𝜎
# 𝑋
# σ
# X
# ​
#   and
# 𝜎
# 𝑌
# σ
# Y
# ​
#   are the standard deviations of
# 𝑋
# X and
# 𝑌
# Y.
# Step 3.1: Calculate the Standard Deviations
# The formula for the standard deviation
# 𝜎
# σ of a dataset is:
#
# 𝜎
# =
# 1
# 𝑛
# ∑
# 𝑖
# =
# 1
# 𝑛
# (
# 𝑋
# 𝑖
# −
# 𝑋
# ˉ
# )
# 2
# σ=
# n
# 1
# ​
#
# i=1
# ∑
# n
# ​
#  (X
# i
# ​
#  −
# X
# ˉ
#  )
# 2
#
# ​
#
# For
# 𝑋
# X (Hours Studied):
#
# 𝜎
# 𝑋
# =
# 1
# 5
# [
# (
# −
# 2
# )
# 2
# +
# (
# −
# 1
# )
# 2
# +
# 0
# 2
# +
# 1
# 2
# +
# 2
# 2
# ]
# =
# 1
# 5
# [
# 4
# +
# 1
# +
# 0
# +
# 1
# +
# 4
# ]
# =
# 10
# 5
# =
# 2
# ≈
# 1.41
# σ
# X
# ​
#  =
# 5
# 1
# ​
#  [(−2)
# 2
#  +(−1)
# 2
#  +0
# 2
#  +1
# 2
#  +2
# 2
#  ]
# ​
#  =
# 5
# 1
# ​
#  [4+1+0+1+4]
# ​
#  =
# 5
# 10
# ​
#
# ​
#  =
# 2
# ​
#  ≈1.41
# For
# 𝑌
# Y (Exam Scores):
#
# 𝜎
# 𝑌
# =
# 1
# 5
# [
# (
# −
# 10
# )
# 2
# +
# (
# −
# 5
# )
# 2
# +
# 0
# 2
# +
# 5
# 2
# +
# 1
# 0
# 2
# ]
# =
# 1
# 5
# [
# 100
# +
# 25
# +
# 0
# +
# 25
# +
# 100
# ]
# =
# 250
# 5
# =
# 50
# ≈
# 7.07
# σ
# Y
# ​
#  =
# 5
# 1
# ​
#  [(−10)
# 2
#  +(−5)
# 2
#  +0
# 2
#  +5
# 2
#  +10
# 2
#  ]
# ​
#  =
# 5
# 1
# ​
#  [100+25+0+25+100]
# ​
#  =
# 5
# 250
# ​
#
# ​
#  =
# 50
# ​
#  ≈7.07
# Step 3.2: Calculate the Correlation
# Now, we can calculate the correlation:
#
# 𝑟
# =
# Cov
# (
# 𝑋
# ,
# 𝑌
# )
# 𝜎
# 𝑋
# 𝜎
# 𝑌
# =
# 10
# 1.41
# ×
# 7.07
# =
# 10
# 9.97
# ≈
# 1.00
# r=
# σ
# X
# ​
#  σ
# Y
# ​
#
# Cov(X,Y)
# ​
#  =
# 1.41×7.07
# 10
# ​
#  =
# 9.97
# 10
# ​
#  ≈1.00
# So, the correlation between Hours Studied and Exam Score is approximately 1.00.
#
# Step 4: Interpretation of Results
# Covariance:
#
# The covariance between the hours studied and the exam score is 10, which indicates a positive relationship between the two variables. However, covariance alone does not give us a standardized measure of the strength of this relationship.
# Correlation:
#
# The correlation is approximately 1.00, which indicates a strong positive linear relationship between the number of hours studied and the exam score. As the number of hours studied increases, the exam score tends to increase as well.
#
# A correlation of 1.00 means that the two variables are perfectly positively related. In other words, for this dataset, if the number of hours studied increases, the exam score increases in a perfectly predictable manner.
#
# Summary
# Covariance measures the direction of the relationship between two variables, but it is not standardized, so its magnitude depends on the units of the variables.
# Correlation measures both the direction and the strength of the linear relationship between two variables, providing a value between -1 and 1. A value of 1 indicates a perfect positive linear relationship.
